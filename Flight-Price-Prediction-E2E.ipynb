# %% [markdown]
# # Flight Price Prediction
# **by Ramy Gendy**

# %% [markdown]
# ## Problem Statment

# %% [markdown]
# Airline industry is one of the most sophisticated in its use of dynamic pricing strategies to maximize revenue, based on proprietary algorithms and hidden variables. Therefore, it is challenging for consumers to predict the price change just by observation. In this project, I built up models to predict the airline’s flight ticket prices.

# %% [markdown]
# ## Data Preparation and Exploration

# %%
# Static image generation
# $ conda install -c conda-forge python-kaleido
# !pip install -U kaleido &> /dev/null

# %%
# Importing libraries
# Numpy for array operations and also to do calculations
import numpy as np
# Pandas for load dataset and manipulation of tabular data
import pandas as pd
# For plotting 
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff
import matplotlib.pyplot as plt
# %matplotlib inline

#from matplotlib import rcParams
#import matplotlib.gridspec as gridspec
#from IPython.core.pylabtools import figsize
#from datasist.structdata import detect_outliers

# For importing dataset from url
import urllib.request
# To interact with the underlying Operating System
import os
# For numerical computation and ML modeling phase 
import tensorflow as tf
# to manipulate date and time
from datetime import datetime, timedelta
# Generate words cloud
from wordcloud import WordCloud
# import Images to notebook
from IPython.display import Image
# 
from scipy import stats

# %%
# Set warnings to be ignored
import warnings
#warnings.filterwarnings("ignore")

# %%
# Export plotly graphs to image
if not os.path.exists("images"):
    os.mkdir("images")

# %%
# Maximzing view
#pd.set_option("display.max_rows", None)

# %%
# Download dataset from repo raw file link is a must to be able to load the file
# &> /dev/null
# !wget https://raw.githubusercontent.com/RamyGendy/Airline-Flight-Price-Prediction/main/Data_Train.xlsx
# Out:
# --2023-06-08 08:36:12--  https://raw.githubusercontent.com/RamyGendy/Airline-Flight-Price-Prediction/main/Data_Train.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 634522 (620K) [application/octet-stream]
# Saving to: ‘Data_Train.xlsx’
#
# Data_Train.xlsx     100%[===================>] 619.65K  --.-KB/s    in 0.008s
#
# 2023-06-08 08:36:12 (80.0 MB/s) - ‘Data_Train.xlsx’ saved [634522/634522]

# %%
# Installing `openpyxl` may be required to access dataset # !pip install openpyxl
# Read dataset from xlsx file, engine='openpyxl' 
df = pd.read_excel('Data_Train.xlsx', engine='openpyxl')

# %%
# Explore first 5 observations
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# **Data Understanding:**
#
# 1. `Airline`: Name of the airline used for traveling.
# 2. `Date_of_Journey`: Date at which a person traveled.
# 3. `Source`: Starting location of flight.
# 4. `Destination`: Ending location of flight.
# 5. `Route`: This contains information on starting and ending location of the journey in the standard format used by airlines.
# 6. `Dep_Time`: Departure time of flight from starting location.
# 7. `Arrival_Time`: Arrival time of flight at destination.
# 8. `Duration`: Duration of flight in hours/minutes.
# 9. `Total_Stops`: Number of total stops flight took before landing at the destination.
# 10. `Additional_Info`: Show any additional information about a flight.
# 11. `Price`: Price of the flight

# %%
# Dataframe shape
df.shape
# Out:
# (10683, 11)

# %%
# Information Summery
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
# Statistical Description
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
# View dataframe columns
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# **Content:**
#
# 1. Data Cleaning.
# 2. Anomally Detection.
# 2. Data Integration.

# %% [markdown]
# ### Missing Values:

# %%
# Check missing values
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
# View observations with missing values
df[df.isnull().any(axis=1)]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
# Drop the null values
df.dropna(inplace=True)

# %% [markdown]
# ### Duplicates:

# %%
# Check for duplicated values
df.duplicated().sum()
# Out:
# 220

# %%
# Check if duplicated values
duplicated_df=df[df.duplicated()]
duplicated_df.shape
# Out:
# (220, 11)

# %%
# Sort duplicated observations together
duplicates = df.duplicated()
df_sorted = df[duplicates].sort_values(by='Price')
df_sorted.head(10)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 3711      SpiceJet      24/03/2019  Banglore   New Delhi
# 2870      SpiceJet      24/03/2019  Banglore   New Delhi
# 6770        IndiGo      24/03/2019  Banglore   New Delhi
# 9097        IndiGo      24/03/2019  Banglore   New Delhi
# 5470       Vistara      24/03/2019  Banglore   New Delhi
# 6881        IndiGo      24/03/2019  Banglore   New Delhi
# 8174   Jet Airways      21/03/2019     Delhi      Cochin
# 10115       IndiGo      09/03/2019  Banglore   New Delhi
# 7502      SpiceJet      03/03/2019  Banglore   New Delhi
# 1704        IndiGo      09/03/2019  Banglore   New Delhi
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 3711               BLR → DEL    20:30         23:20   2h 50m    non-stop
# 2870               BLR → DEL    05:45         08:35   2h 50m    non-stop
# 6770               BLR → DEL    06:00         08:45   2h 45m    non-stop
# 9097               BLR → DEL    04:00         06:50   2h 50m    non-stop
# 5470               BLR → DEL    11:30         14:10   2h 40m    non-stop
# 6881               BLR → DEL    07:10         10:05   2h 55m    non-stop
# 8174   DEL → AMD → BOM → COK    19:10  18:50 22 Mar  23h 40m     2 stops
# 10115              BLR → DEL    10:05         13:00   2h 55m    non-stop
# 7502               BLR → DEL    20:30         23:20   2h 50m    non-stop
# 1704               BLR → DEL    18:25         21:20   2h 55m    non-stop
#
#                     Additional_Info  Price
# 3711   No check-in baggage included   3873
# 2870   No check-in baggage included   4273
# 6770                        No info   4777
# 9097                        No info   4777
# 5470                        No info   5403
# 6881                        No info   6144
# 8174    In-flight meal not included   6643
# 10115                       No info   6860
# 7502                        No info   6860
# 1704                        No info   6860

# %%
# Display original and duplicated observations
df[duplicates]
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 683    Jet Airways       1/06/2019     Delhi      Cochin
# 1061     Air India      21/05/2019     Delhi      Cochin
# 1348     Air India      18/05/2019     Delhi      Cochin
# 1418   Jet Airways       6/06/2019     Delhi      Cochin
# 1674        IndiGo      24/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10594  Jet Airways      27/06/2019     Delhi      Cochin
# 10616  Jet Airways       1/06/2019     Delhi      Cochin
# 10634  Jet Airways       6/06/2019     Delhi      Cochin
# 10672  Jet Airways      27/06/2019     Delhi      Cochin
# 10673  Jet Airways      27/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 683    DEL → NAG → BOM → COK    14:35  04:25 02 Jun  13h 50m     2 stops
# 1061   DEL → GOI → BOM → COK    22:00  19:15 22 May  21h 15m     2 stops
# 1348   DEL → HYD → BOM → COK    17:15  19:15 19 May      26h     2 stops
# 1418   DEL → JAI → BOM → COK    05:30  04:25 07 Jun  22h 55m     2 stops
# 1674               BLR → DEL    18:25         21:20   2h 55m    non-stop
# ...                      ...      ...           ...      ...         ...
# 10594  DEL → AMD → BOM → COK    23:05  12:35 28 Jun  13h 30m     2 stops
# 10616  DEL → JAI → BOM → COK    09:40  12:35 02 Jun  26h 55m     2 stops
# 10634  DEL → JAI → BOM → COK    09:40  12:35 07 Jun  26h 55m     2 stops
# 10672  DEL → AMD → BOM → COK    23:05  19:00 28 Jun  19h 55m     2 stops
# 10673  DEL → AMD → BOM → COK    13:25  04:25 28 May      15h     2 stops
#
#                    Additional_Info  Price
# 683                        No info  13376
# 1061                       No info  10231
# 1348                       No info  12392
# 1418   In-flight meal not included  10368
# 1674                       No info   7303
# ...                            ...    ...
# 10594                      No info  12819
# 10616                      No info  13014
# 10634  In-flight meal not included  11733
# 10672  In-flight meal not included  11150
# 10673                      No info  16704
#
# [220 rows x 11 columns]

# %%
# Total number of duplicated values
DupToTot = round((df.duplicated().sum())*100/len(df))
print ("Duplicated values in {} is about {} % of {} total values.".format(df.duplicated().sum(),DupToTot,len(df)))
if DupToTot < 10:
  print ("Removel of duplication is accepted.")
else:
    print ("Removel of duplication is NOT accepted.")
# Out:
# Duplicated values in 220 is about 2 % of 10682 total values.
# Removel of duplication is accepted.

# %%
# Remove duplicated values
df.drop_duplicates(inplace=True)

# %% [markdown]
# **Summary:**
#
# * There is two missing values in features in one observation (`9039`): `Total_Stops` and `Route`.
# * Wrong Datatype in `Date_of_Journey`, `Dep_Time`, `Arrival_Time` and `Duration` : expected to be presented as `Date/time` format but found as `Object`.
# * Wrong Datatype in `Total_Stops` : expected to be `Integer` but found as `Object`
# * `Additional_Info` seems to have a lot of not relevant information.
# * `220` duplicated observations within our dataframe were removed.

# %% [markdown]
# ### Features Exploration

# %% [markdown]
# #### Airline Company:

# %%
# 1st Feature: `Airline` unique values
df["Airline"].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
# Count values in `Airline` feature
df["Airline"].value_counts()
# Out:
# Jet Airways                          3700
# IndiGo                               2043
# Air India                            1694
# Multiple carriers                    1196
# SpiceJet                              815
# Vistara                               478
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
# Plot Airline count
ax = sns.countplot(data=df, y="Airline", color = sns.color_palette()[0], order=df['Airline'].value_counts().index)
ax.bar_label(ax.containers[0]);

# %% [markdown]
# **Observations:**
#
# * `Multiple carriers` is duplicated as `Multiple carriers Premium economy`.
# * `Vistara` is duplicated as `Vistara Premium economy`.
# * `Jet Airways` is splited into `Jet Airways` and `Jet Airways Business`
# * `Trujet` has only one entry.

# %%
# Investigating `Multiple carriers Premium economy` observations
df[df["Airline"]=="Multiple carriers Premium economy"]
# Out:
#                                 Airline Date_of_Journey Source Destination  \
# 717   Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 1799  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 4627  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 4718  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 5090  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 5489  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 5673  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 5836  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 6470  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 6591  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 6601  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 9249  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
# 9253  Multiple carriers Premium economy      21/03/2019  Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 717   DEL → BOM → COK    07:30         19:15  11h 45m      1 stop
# 1799  DEL → BOM → COK    07:30         21:00  13h 30m      1 stop
# 4627  DEL → BOM → COK    08:55         19:15  10h 20m      1 stop
# 4718  DEL → BOM → COK    06:00         21:00      15h      1 stop
# 5090  DEL → BOM → COK    06:00         13:20   7h 20m      1 stop
# 5489  DEL → BOM → COK    06:00         15:30   9h 30m      1 stop
# 5673  DEL → BOM → COK    06:00         18:50  12h 50m      1 stop
# 5836  DEL → BOM → COK    07:30         18:50  11h 20m      1 stop
# 6470  DEL → BOM → COK    08:55         21:00   12h 5m      1 stop
# 6591  DEL → BOM → COK    08:55         15:30   6h 35m      1 stop
# 6601  DEL → BOM → COK    06:00         12:35   6h 35m      1 stop
# 9249  DEL → BOM → COK    19:00  01:35 22 Mar   6h 35m      1 stop
# 9253  DEL → BOM → COK    07:30         15:30       8h      1 stop
#
#      Additional_Info  Price
# 717          No info  10161
# 1799         No info   9845
# 4627         No info  10161
# 4718         No info   9845
# 5090         No info  11269
# 5489         No info  11269
# 5673         No info  14629
# 5836         No info  14629
# 6470         No info   9845
# 6591         No info  11269
# 6601         No info  13369
# 9249         No info  10885
# 9253         No info  11269

# %% [markdown]
# * the `Airline` feature contains `Multiple carriers Premium economy` observations which basically the same company `Multiple carriers` but with different name, therefore we will replace `Multiple carriers Premium economy` values with the company name `Multiple carriers` values and add the `Premium economy` values to `Addtional_info`.

# %%
# Adding `Premium economy` values to `Addtional_info`
df.loc[
    df["Airline"]=="Multiple carriers Premium economy",
     "Additional_Info"] = df.loc[
        df["Airline"]=="Multiple carriers Premium economy",
         "Additional_Info"].replace('No info', 'Premium economy')

# %%
# Replace `Multiple carriers Premium economy` with `Multiple carriers`
df['Airline'].replace(
    'Multiple carriers Premium economy',
     'Multiple carriers',
      inplace = True)

# %%
# Investigating `Jet Airways Business` observations
df[df["Airline"]=="Jet Airways Business"]
# Out:
#                     Airline Date_of_Journey    Source Destination  \
# 657    Jet Airways Business      01/03/2019  Banglore   New Delhi
# 2924   Jet Airways Business      01/03/2019  Banglore   New Delhi
# 5372   Jet Airways Business      01/03/2019  Banglore   New Delhi
# 7351   Jet Airways Business       3/03/2019     Delhi      Cochin
# 9715   Jet Airways Business       6/03/2019     Delhi      Cochin
# 10364  Jet Airways Business      01/03/2019  Banglore   New Delhi
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 657          BLR → BOM → DEL    05:45         10:45       5h      1 stop
# 2924         BLR → BOM → DEL    05:45         11:25   5h 40m      1 stop
# 5372         BLR → BOM → DEL    05:45         12:25   6h 40m      1 stop
# 7351   DEL → ATQ → BOM → COK    20:05  04:25 04 Mar   8h 20m     2 stops
# 9715   DEL → ATQ → BOM → COK    20:05  04:25 07 Mar   8h 20m     2 stops
# 10364        BLR → MAA → DEL    09:45         14:25   4h 40m      1 stop
#
#       Additional_Info  Price
# 657           No info  52229
# 2924   Business class  79512
# 5372   Business class  62427
# 7351          No info  46490
# 9715          No info  52285
# 10364  Business class  57209

# %% [markdown]
# * the `Airline` feature contains `Jet Airways Business` observations which basically the same company `Jet Airways` but with different name, therefore we will replace `Jet Airways Business` values with the company name `Jet Airways` values and add the `Business` as `Business class` values in `Addtional_info`.

# %%
# Adding `Business class` values of `Jet Airways Business` to `Addtional_info`
df.loc[
    df["Airline"]=="Jet Airways Business",
     "Additional_Info"] = df.loc[
        df["Airline"]=="Jet Airways Business",
         "Additional_Info"].replace('No info', 'Business class')

# %%
# Replace `Jet Airways Business` with `Jet Airways`
df['Airline'].replace(
    'Jet Airways Business',
     'Jet Airways',
      inplace = True)

# %%
# Investigating `Vistara Premium economy` observations
df[df["Airline"]=="Vistara Premium economy"]
# Out:
#                       Airline Date_of_Journey    Source Destination  \
# 426   Vistara Premium economy      03/03/2019  Banglore   New Delhi
# 7657  Vistara Premium economy       1/03/2019   Chennai     Kolkata
# 8615  Vistara Premium economy       6/04/2019  Banglore       Delhi
#
#           Route Dep_Time Arrival_Time Duration Total_Stops Additional_Info  \
# 426   BLR → DEL    16:00        18:35   2h 35m    non-stop         No info
# 7657  MAA → CCU    07:05        09:20   2h 15m    non-stop         No info
# 8615  BLR → DEL    11:30        14:20   2h 50m    non-stop         No info
#
#       Price
# 426   11793
# 7657   9125
# 8615   5969

# %% [markdown]
# * the `Airline` feature contains `Vistara Premium economy` observations which basically the same company `Vistara` but with different name, therefore we will replace `Vistara Premium economy` values with the company name `Vistara` values and add the `Premium economy` values to `Addtional_info`.

# %%
# Adding `Premium economy` values to `Addtional_info`
df.loc[
    df["Airline"]=="Vistara Premium economy",
     "Additional_Info"] = df.loc[
        df["Airline"]=="Vistara Premium economy",
         "Additional_Info"].replace('No info', 'Premium economy')

# %%
# Replace `Vistara Premium economy` with `Vistara`
df['Airline'].replace(
    'Vistara Premium economy',
     'Vistara',
      inplace = True)

# %% [markdown]
# **Points of Considerations:**
#
# * Considering anomalies in data, also known as outliers, are observations that deviate significantly from the norm or general distribution of the data. These observations can be unusual or unexpected and may indicate errors, unusual behavior, or interesting phenomena.
#
# * Anomalies can arise due to various reasons such as measurement errors, data entry errors, data processing errors, or natural deviations in the data.
#
# * Detecting and handling anomalies is an important step in data analysis as they can have a significant impact on the results of statistical analysis and machine learning models.

# %%
# Calculate the frequency of each category
freq = df['Airline'].value_counts(normalize=True)

# Flag categories with a frequency below the threshold as potential anomalies
threshold = 0.01
anomalies = freq[freq < threshold].index
print("Anomalies in `Airline` feature that will be dropped:", anomalies)
# Out:
# Anomalies in `Airline` feature that will be dropped: Index(['Trujet'], dtype='object')

# %%
# View anomaly 
df[df["Airline"]=="Trujet"]
# Out:
#      Airline Date_of_Journey  Source Destination            Route Dep_Time  \
# 2878  Trujet       6/03/2019  Mumbai   Hyderabad  BOM → NDC → HYD    13:05
#
#      Arrival_Time Duration Total_Stops Additional_Info  Price
# 2878        16:20   3h 15m      1 stop         No info   4140

# %%
# Dropping anomalies
df = df[df["Airline"] != str(anomalies[0])]

# %% [markdown]
# **Observations:**
#
# * All trips are in same year `2019`.
# * All trips are within the month `03, 04, 05, 06`.
# * All trips are within certain days `1, 3, 6, 9, 12, 15, 18, 21, 24, 27`.
# * There are duplicated days in form of `01 & 1`, `03 & 3` and `09 & 9`.

# %%
# Plot Airline count
ax = sns.countplot(data=df, y="Airline", color = sns.color_palette()[0], order=df['Airline'].value_counts().index)
ax.bar_label(ax.containers[0]);

# %% [markdown]
# #### Departure:

# %%
# 3rd Feature: `Source` unique values
df["Source"].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
# `Source` value counts
df["Source"].value_counts()
# Out:
# Delhi       4345
# Kolkata     2860
# Banglore    2179
# Mumbai       696
# Chennai      381
# Name: Source, dtype: int64

# %%
# Plot `Source` count
ax = sns.countplot(data=df, y="Source", color = sns.color_palette()[0], order=df['Source'].value_counts().index)
ax.bar_label(ax.containers[0]);

# %% [markdown]
# #### Arrival Destination:

# %%
# 4th Feature: `Destination` unique values
df["Destination"].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
# `Destination` value counts
df["Destination"].value_counts()
# Out:
# Cochin       4345
# Banglore     2860
# Delhi        1265
# New Delhi     914
# Hyderabad     696
# Kolkata       381
# Name: Destination, dtype: int64

# %%
# Plot `Destination` count
ax = sns.countplot(data=df, y="Destination", color = sns.color_palette()[0], order=df['Destination'].value_counts().index)
ax.bar_label(ax.containers[0]);

# %% [markdown]
# **Airport codes:**
#
# * **Kolkata**   : `CCU` (Netaji Subhash Chandra Bose International Airport)
# * **Bangalore** : `BLR` (Bengaluru International Airport)
# * **Mumbai**    : `BOM` (Chhatrapati Shivaji International Airport)
# * **Chennai**   : `MAA` (Meenambarkkam International Airport)
# * **Cochin**    : `COK` (Cochin International Airport)
# * **Hyderabad** : `HYD` (Rajiv Gandhi International Airport)
# * **Delhi**     : `DEL` (Indira Gandhi International Airport)
# * **New Delhi** : `DEL` (Indira Gandhi International Airport)
#
# With simple search it was found that both **Delhi** and **New Delhi** shares the same airport. that means it's the same.

# %% [markdown]
# By Double checking by intersecting `Destination` with `Route` with **Delhi** & **New Delhi**, it's clear that **Delhi** and **New Delhi** have have the same airport with code `DEL`

# %%
# Replace `'New Delhi` with `Delhi` as both have the same airport
df['Destination'].replace('New Delhi','Delhi', inplace = True)

# %%
# Plot `Destination` count
ax = sns.countplot(data=df, y="Destination", color = sns.color_palette()[0], order=df['Destination'].value_counts().index)
ax.bar_label(ax.containers[0]);

# %% [markdown]
# #### Flight Route & Stops:

# %%
# 5th Feature: `Route` unique values
df["Route"].unique()
# Out:
# array(['BLR → DEL', 'CCU → IXR → BBI → BLR', 'DEL → LKO → BOM → COK',
#        'CCU → NAG → BLR', 'BLR → NAG → DEL', 'CCU → BLR',
#        'BLR → BOM → DEL', 'DEL → BOM → COK', 'DEL → BLR → COK',
#        'MAA → CCU', 'CCU → BOM → BLR', 'DEL → AMD → BOM → COK',
#        'DEL → PNQ → COK', 'DEL → CCU → BOM → COK', 'BLR → COK → DEL',
#        'DEL → IDR → BOM → COK', 'DEL → LKO → COK',
#        'CCU → GAU → DEL → BLR', 'DEL → NAG → BOM → COK',
#        'CCU → MAA → BLR', 'DEL → HYD → COK', 'CCU → HYD → BLR',
#        'DEL → COK', 'CCU → DEL → BLR', 'BLR → BOM → AMD → DEL',
#        'BOM → DEL → HYD', 'DEL → MAA → COK', 'BOM → HYD',
#        'DEL → BHO → BOM → COK', 'DEL → JAI → BOM → COK',
#        'DEL → ATQ → BOM → COK', 'DEL → JDH → BOM → COK',
#        'CCU → BBI → BOM → BLR', 'BLR → MAA → DEL',
#        'DEL → GOI → BOM → COK', 'DEL → BDQ → BOM → COK',
#        'CCU → JAI → BOM → BLR', 'CCU → BBI → BLR', 'BLR → HYD → DEL',
#        'DEL → TRV → COK', 'CCU → IXR → DEL → BLR',
#        'DEL → IXU → BOM → COK', 'CCU → IXB → BLR',
#        'BLR → BOM → JDH → DEL', 'DEL → UDR → BOM → COK',
#        'DEL → HYD → MAA → COK', 'CCU → BOM → COK → BLR',
#        'BLR → CCU → DEL', 'CCU → BOM → GOI → BLR',
#        'DEL → RPR → NAG → BOM → COK', 'DEL → HYD → BOM → COK',
#        'CCU → DEL → AMD → BLR', 'CCU → PNQ → BLR',
#        'BLR → CCU → GAU → DEL', 'CCU → DEL → COK → BLR',
#        'BLR → PNQ → DEL', 'BOM → JDH → DEL → HYD',
#        'BLR → BOM → BHO → DEL', 'DEL → AMD → COK', 'BLR → LKO → DEL',
#        'CCU → GAU → BLR', 'BOM → GOI → HYD', 'CCU → BOM → AMD → BLR',
#        'CCU → BBI → IXR → DEL → BLR', 'DEL → DED → BOM → COK',
#        'DEL → MAA → BOM → COK', 'BLR → AMD → DEL', 'BLR → VGA → DEL',
#        'CCU → JAI → DEL → BLR', 'CCU → AMD → BLR',
#        'CCU → VNS → DEL → BLR', 'BLR → BOM → IDR → DEL',
#        'BLR → BBI → DEL', 'BLR → GOI → DEL', 'BOM → AMD → ISK → HYD',
#        'BOM → DED → DEL → HYD', 'DEL → IXC → BOM → COK',
#        'CCU → PAT → BLR', 'BLR → CCU → BBI → DEL',
#        'CCU → BBI → HYD → BLR', 'BLR → BOM → NAG → DEL',
#        'BLR → CCU → BBI → HYD → DEL', 'BLR → GAU → DEL',
#        'BOM → BHO → DEL → HYD', 'BOM → JLR → HYD',
#        'BLR → HYD → VGA → DEL', 'CCU → KNU → BLR',
#        'CCU → BOM → PNQ → BLR', 'DEL → BBI → COK',
#        'BLR → VGA → HYD → DEL', 'BOM → JDH → JAI → DEL → HYD',
#        'DEL → GWL → IDR → BOM → COK', 'CCU → RPR → HYD → BLR',
#        'CCU → VTZ → BLR', 'CCU → DEL → VGA → BLR',
#        'BLR → BOM → IDR → GWL → DEL', 'CCU → DEL → COK → TRV → BLR',
#        'BOM → COK → MAA → HYD', 'BLR → BDQ → DEL',
#        'CCU → BOM → TRV → BLR', 'CCU → BOM → HBX → BLR',
#        'BOM → BDQ → DEL → HYD', 'BOM → CCU → HYD',
#        'BLR → TRV → COK → DEL', 'BLR → IDR → DEL',
#        'CCU → IXZ → MAA → BLR', 'CCU → GAU → IMF → DEL → BLR',
#        'BOM → GOI → PNQ → HYD', 'BOM → BLR → CCU → BBI → HYD',
#        'BOM → MAA → HYD', 'BLR → BOM → UDR → DEL',
#        'BOM → UDR → DEL → HYD', 'BLR → VGA → VTZ → DEL',
#        'BLR → HBX → BOM → BHO → DEL', 'CCU → IXA → BLR',
#        'BOM → RPR → VTZ → HYD', 'BLR → HBX → BOM → AMD → DEL',
#        'BOM → IDR → DEL → HYD', 'BOM → BLR → HYD', 'BLR → STV → DEL',
#        'CCU → IXB → DEL → BLR', 'BOM → JAI → DEL → HYD',
#        'BOM → VNS → DEL → HYD', 'BLR → HBX → BOM → NAG → DEL',
#        'BLR → BOM → IXC → DEL', 'BLR → CCU → BBI → HYD → VGA → DEL',
#        'BOM → BBI → HYD'], dtype=object)

# %%
# `Route` value counts
df["Route"].value_counts()
# Out:
# DEL → BOM → COK          2376
# BLR → DEL                1536
# CCU → BOM → BLR           979
# CCU → BLR                 724
# BOM → HYD                 621
#                          ...
# CCU → RPR → HYD → BLR       1
# CCU → VTZ → BLR             1
# CCU → IXZ → MAA → BLR       1
# BOM → COK → MAA → HYD       1
# BOM → BBI → HYD             1
# Name: Route, Length: 127, dtype: int64

# %%
# 9th Feature: `Total_Stops` unique values
df["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
# `Total_Stops` value counts
df["Total_Stops"].value_counts()
# Out:
# 1 stop      5624
# non-stop    3475
# 2 stops     1318
# 3 stops       43
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
# Plot `Total_Stops` count
ax = sns.countplot(data=df, y="Total_Stops", color = sns.color_palette()[0], order=df['Total_Stops'].value_counts().index)
ax.bar_label(ax.containers[0]);

# %%
# View observations where column 'Total_Stops' has the value '4 stops'
df[df['Total_Stops'] == '4 stops']
# Out:
#         Airline Date_of_Journey    Source Destination  \
# 9182  Air India      01/03/2019  Banglore       Delhi
#
#                                   Route Dep_Time  Arrival_Time Duration  \
# 9182  BLR → CCU → BBI → HYD → VGA → DEL    05:50  11:20 02 Mar  29h 30m
#
#      Total_Stops  Additional_Info  Price
# 9182     4 stops  Change airports  17686

# %%
# Dropping anomalies
df = df[df["Total_Stops"] != '4 stops']
df = df[df["Total_Stops"] != '3 stops']

# %%
#df['Total_Stops'] = df['Total_Stops'].map({'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, '4 stops':4})

# %%
# Creating number of stops from `Route`
df["routes_count"] = df["Route"].str.count('→') - 1

# %%
# Plot `routes_count` count
ax = sns.countplot(data=df, y="routes_count", color = sns.color_palette()[0], order=df['routes_count'].value_counts().index)
ax.bar_label(ax.containers[0]);

# %%
# Dropping anomalies
df = df[df["Airline"] != str(anomalies[0])]

# %%
# Verifing the total stops
#df[df["routes_count"]!=df["Total_Stops"]].shape

# %% [markdown]
# #### Additional Flgiht Infomation

# %%
# 9th Feature: `Additional_Info` unique values
df["Additional_Info"].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', 'Premium economy',
#        'Business class', '1 Short layover', 'No Info', '1 Long layover',
#        'Change airports', 'Red-eye flight', '2 Long layover'],
#       dtype=object)

# %%
# `Additional_Info` value counts
df["Additional_Info"].value_counts()
# Out:
# No info                         8119
# In-flight meal not included     1926
# No check-in baggage included     318
# 1 Long layover                    19
# Premium economy                   16
# Business class                     7
# Change airports                    6
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(str(df.Additional_Info.value_counts()))

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show();

# %% [markdown]
# **Feature values explaination:**
#
# * `Red-eye flight` meaning: flights that depart at night and arrive the next morning, especially when the total flight time is insufficient for passengers to get a full night’s sleep. The term derives from red eyes as a symptom of fatigue. Red-eye flights usually take off after 9 p.m. and arrive by 5 or 6 a.m.
# * `layover` is the time between two connecting flights.
# * `long layover` usually lasts around four hours for domestic flights and 24 hours for international flights .
# * `short layover` is typically just a few hours and is designed to give passengers some breathing room while changing planes .

# %% [markdown]
# #### Flight Price:

# %%
# 10th Feature: `Price` statistical description 
df["Price"].describe()
# Out:
# count    10417.000000
# mean      9008.951234
# std       4622.002688
# min       1759.000000
# 25%       5224.000000
# 50%       8224.000000
# 75%      12295.000000
# max      79512.000000
# Name: Price, dtype: float64

# %% [markdown]
# * The `mean` will be greater than the `median (50% count)`, our target is `Positively/Right skewed`.

# %%
# 10th Feature: `Price` distribution
sns.displot(df["Price"], kde=True, bins=30, color='blue', height=5, aspect=1.5);

# %%
# Check for outliers
fig1 = px.histogram(df, x="Price", histnorm='probability density',marginal="box")
#fig.update_layout(autosize=False,width=800,height=500,)
fig1.show();
# Save images to folder
fig1.write_image("images/fig1.png", engine="kaleido")
Image('images/fig1.png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="93104205-c535-4b19-bd54-d0e6a5210b7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93104205-c535-4b19-bd54-d0e6a5210b7c")) {                    Plotly.newPlot(                        "93104205-c535-4b19-bd54-d0e6a5210b7c",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":"Price=%{x}<br>probability density=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[3897,7662,13882,6218,13302,3873,11087,22270,11087,8625,8907,4174,4667,9663,4804,14011,5830,10262,13381,12898,19495,6955,3943,4823,7757,13292,8238,7682,4668,3687,3687,13227,4423,10919,12373,5894,4649,6245,19225,14924,9646,8714,12373,3383,13062,3527,3943,4667,6117,11150,7202,12121,4377,3943,4483,14231,17345,7414,8073,12395,8366,5117,12524,7191,3687,5894,5403,3625,10861,6297,5678,9134,10791,12819,6893,7240,3898,4049,10262,3332,10844,7229,13941,5894,10197,13712,5636,13014,7064,10703,9646,17057,13817,13748,4880,3540,3257,6478,8040,14300,14781,14939,10262,6528,6121,13029,11421,7574,11596,15129,13555,5780,9397,17024,5281,10348,12677,15147,4668,15554,3971,3100,9663,27430,3540,10676,13044,14388,3943,3597,5932,10262,6216,4804,14067,15129,13376,10441,4030,17024,13017,6686,5636,6442,9486,10844,15318,5117,6147,7005,3873,9270,3898,14781,8586,10697,14300,8855,10844,17024,9314,4777,7662,6442,5264,12898,6092,3311,6540,3419,5177,8246,14676,13587,9663,13044,5073,9345,9663,14277,10262,5678,13727,9663,3858,4812,5775,10539,4804,3383,8738,7165,6412,8016,11087,3543,12471,10262,4441,12537,10091,6961,5013,6934,10877,7229,7048,4878,10844,15129,3943,5583,9646,7677,6842,4995,9555,4077,7229,12192,5911,8372,4995,14323,13014,13591,18799,3943,1965,4995,14641,4460,10191,13843,6349,4409,17024,13727,8855,12524,13555,10844,13587,3543,4842,3943,10577,6979,11982,5264,8001,10651,10844,6601,6587,3173,5228,5769,14714,13014,3359,6722,4462,6171,12303,7695,5684,8366,19630,13502,14781,6513,9929,18275,4487,2754,2575,8224,8991,5000,8529,14042,4030,10844,4804,7308,4823,10262,12898,12778,14871,8708,10844,4129,4804,7229,7832,3859,9001,4878,2754,4668,5216,10368,8146,12242,9134,10939,11753,4174,10844,14714,9899,14871,7295,13465,3543,7198,10262,4148,8016,10262,3841,11507,14781,16079,12898,15353,7303,6197,8996,6528,4239,4148,3971,5192,9483,18804,5201,16079,7229,6795,10953,15965,9968,4804,16079,11507,11542,7229,4544,6496,4804,13439,6540,4591,4437,6151,7754,10262,8016,4781,4668,14594,14231,8425,9646,7295,5162,6860,6216,5192,4823,3919,2754,9315,11667,6224,13349,11087,15603,15129,4823,8452,12524,3384,10262,1965,4804,16079,13292,6751,8669,14871,12898,3919,36983,3597,10741,11432,11087,13292,7631,13381,13731,11911,4591,14848,8266,12392,13044,12898,12242,3943,11105,14388,13014,15411,16289,6442,10844,5678,6906,3543,14714,11793,14323,3971,8452,5403,13727,12639,5198,4878,12373,8552,6741,6481,7354,5228,10844,6347,5013,9663,4823,13381,3543,9663,7064,10262,13013,15339,4937,6818,10441,5177,3858,6534,6795,9736,7229,4957,7648,3873,14388,5618,7408,13774,4668,13082,8669,6316,12583,7923,7378,4878,10844,7229,6297,8529,13727,6643,10197,4911,6482,26890,3717,3597,10846,14069,5177,14641,6442,5704,9663,14714,5406,8610,14237,4823,2227,12373,8372,17024,3100,14053,3540,9345,10368,26890,5755,7832,14388,8839,22096,3687,9627,13542,4423,8899,5583,6752,3543,7832,10991,12898,12898,3398,5201,13873,7384,10262,10031,12384,7757,17261,7298,7229,4174,5699,4880,15284,13759,16092,4392,10262,3841,5048,11096,5073,19828,3739,10598,7229,8610,6216,6961,10703,14151,8586,4488,7408,5443,10539,7723,15411,7229,4804,4050,14151,4957,7591,11134,6600,4966,15481,5515,14714,4959,7229,6094,4409,9794,5678,6442,4878,12446,1670 ...

# %%
# Check for Price distribution 
fig2 = px.histogram(df, x="Price", marginal="violin", hover_data=df.columns)
fig2.show();
# Save images to folder
fig2.write_image("images/fig2.png", engine="kaleido")
Image('images/fig2.png')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9a8eeb43-f335-40f7-b836-9408f466bee9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a8eeb43-f335-40f7-b836-9408f466bee9")) {                    Plotly.newPlot(                        "9a8eeb43-f335-40f7-b836-9408f466bee9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[3897,7662,13882,6218,13302,3873,11087,22270,11087,8625,8907,4174,4667,9663,4804,14011,5830,10262,13381,12898,19495,6955,3943,4823,7757,13292,8238,7682,4668,3687,3687,13227,4423,10919,12373,5894,4649,6245,19225,14924,9646,8714,12373,3383,13062,3527,3943,4667,6117,11150,7202,12121,4377,3943,4483,14231,17345,7414,8073,12395,8366,5117,12524,7191,3687,5894,5403,3625,10861,6297,5678,9134,10791,12819,6893,7240,3898,4049,10262,3332,10844,7229,13941,5894,10197,13712,5636,13014,7064,10703,9646,17057,13817,13748,4880,3540,3257,6478,8040,14300,14781,14939,10262,6528,6121,13029,11421,7574,11596,15129,13555,5780,9397,17024,5281,10348,12677,15147,4668,15554,3971,3100,9663,27430,3540,10676,13044,14388,3943,3597,5932,10262,6216,4804,14067,15129,13376,10441,4030,17024,13017,6686,5636,6442,9486,10844,15318,5117,6147,7005,3873,9270,3898,14781,8586,10697,14300,8855,10844,17024,9314,4777,7662,6442,5264,12898,6092,3311,6540,3419,5177,8246,14676,13587,9663,13044,5073,9345,9663,14277,10262,5678,13727,9663,3858,4812,5775,10539,4804,3383,8738,7165,6412,8016,11087,3543,12471,10262,4441,12537,10091,6961,5013,6934,10877,7229,7048,4878,10844,15129,3943,5583,9646,7677,6842,4995,9555,4077,7229,12192,5911,8372,4995,14323,13014,13591,18799,3943,1965,4995,14641,4460,10191,13843,6349,4409,17024,13727,8855,12524,13555,10844,13587,3543,4842,3943,10577,6979,11982,5264,8001,10651,10844,6601,6587,3173,5228,5769,14714,13014,3359,6722,4462,6171,12303,7695,5684,8366,19630,13502,14781,6513,9929,18275,4487,2754,2575,8224,8991,5000,8529,14042,4030,10844,4804,7308,4823,10262,12898,12778,14871,8708,10844,4129,4804,7229,7832,3859,9001,4878,2754,4668,5216,10368,8146,12242,9134,10939,11753,4174,10844,14714,9899,14871,7295,13465,3543,7198,10262,4148,8016,10262,3841,11507,14781,16079,12898,15353,7303,6197,8996,6528,4239,4148,3971,5192,9483,18804,5201,16079,7229,6795,10953,15965,9968,4804,16079,11507,11542,7229,4544,6496,4804,13439,6540,4591,4437,6151,7754,10262,8016,4781,4668,14594,14231,8425,9646,7295,5162,6860,6216,5192,4823,3919,2754,9315,11667,6224,13349,11087,15603,15129,4823,8452,12524,3384,10262,1965,4804,16079,13292,6751,8669,14871,12898,3919,36983,3597,10741,11432,11087,13292,7631,13381,13731,11911,4591,14848,8266,12392,13044,12898,12242,3943,11105,14388,13014,15411,16289,6442,10844,5678,6906,3543,14714,11793,14323,3971,8452,5403,13727,12639,5198,4878,12373,8552,6741,6481,7354,5228,10844,6347,5013,9663,4823,13381,3543,9663,7064,10262,13013,15339,4937,6818,10441,5177,3858,6534,6795,9736,7229,4957,7648,3873,14388,5618,7408,13774,4668,13082,8669,6316,12583,7923,7378,4878,10844,7229,6297,8529,13727,6643,10197,4911,6482,26890,3717,3597,10846,14069,5177,14641,6442,5704,9663,14714,5406,8610,14237,4823,2227,12373,8372,17024,3100,14053,3540,9345,10368,26890,5755,7832,14388,8839,22096,3687,9627,13542,4423,8899,5583,6752,3543,7832,10991,12898,12898,3398,5201,13873,7384,10262,10031,12384,7757,17261,7298,7229,4174,5699,4880,15284,13759,16092,4392,10262,3841,5048,11096,5073,19828,3739,10598,7229,8610,6216,6961,10703,14151,8586,4488,7408,5443,10539,7723,15411,7229,4804,4050,14151,4957,7591,11134,6600,4966,15481,5515,14714,4959,7229,6094,4409,9794,5678,6442,4878,12446,16704,9134,8586,7229,6144,6961,10844,3597,7139,2513 ...

# %% [markdown]
# * The `positive skewness` is clear with a tail of a distribution curve is longer on the right side.
# * This means the `outliers` of the distribution curve are further out towards the right and closer to the mean on the left.
# * Skewness can affect the performance of our ML models.
# * i.e.: the model will be trained on a much larger number of values in one part of the distribution and will be less likely to successfully predict values in other parts of the distribution.
# * Skewness may also violate model assumptions or impair the interpretation of feature importance.
# * transformations can help reduce skewness and make the data more normally distributed.

# %%
df[(np.abs(stats.zscore(df["Price"])) > 3)]
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 123            Air India      2019-03-01     Delhi      Cochin
# 396    Multiple carriers      2019-03-01     Delhi      Cochin
# 486          Jet Airways      2019-03-01  Banglore       Delhi
# 510          Jet Airways      2019-03-01  Banglore       Delhi
# 597            Air India      2019-03-06    Mumbai   Hyderabad
# ...                  ...             ...       ...         ...
# 10353        Jet Airways      2019-03-06    Mumbai   Hyderabad
# 10364        Jet Airways      2019-03-01  Banglore       Delhi
# 10383        Jet Airways      2019-03-01  Banglore       Delhi
# 10439        Jet Airways      2019-03-01  Banglore       Delhi
# 10511          Air India      2019-03-01  Banglore       Delhi
#
#                        Route  Dep_Time  Arrival_Time Duration Total_Stops  \
# 123          DEL → BOM → COK  23:00:00  19:15 02 Mar  20h 15m      1 stop
# 396          DEL → BOM → COK  12:50:00         19:15   6h 25m      1 stop
# 486          BLR → BOM → DEL  08:55:00         15:15   6h 20m      1 stop
# 510          BLR → BOM → DEL  07:00:00         12:25   5h 25m      1 stop
# 597    BOM → JDH → DEL → HYD  09:40:00  15:15 07 Mar  29h 35m     2 stops
# ...                      ...       ...           ...      ...         ...
# 10353  BOM → BDQ → DEL → HYD  19:50:00  16:50 07 Mar      21h     2 stops
# 10364        BLR → MAA → DEL  09:45:00         14:25   4h 40m      1 stop
# 10383        BLR → BOM → DEL  07:00:00  05:05 02 Mar   22h 5m      1 stop
# 10439        BLR → BOM → DEL  18:40:00  09:00 02 Mar  14h 20m      1 stop
# 10511  BLR → BOM → BHO → DEL  06:45:00  09:25 02 Mar  26h 40m     2 stops
#
#       Additional_Info  Price  routes_count       dep_date_time  \
# 123           No info  27430             1 2019-03-01 23:00:00
# 396           No info  36983             1 2019-03-01 12:50:00
# 486           No info  26890             1 2019-03-01 08:55:00
# 510           No info  26890             1 2019-03-01 07:00:00
# 597           No info  25139             2 2019-03-06 09:40:00
# ...               ...    ...           ...                 ...
# 10353         No info  24210             2 2019-03-06 19:50:00
# 10364  Business class  57209             1 2019-03-01 09:45:00
# 10383         No info  26890             1 2019-03-01 07:00:00
# 10439         No info  31825             1 2019-03-01 18:40:00
# 10511  2 Long layover  26480             2 2019-03-01 06:45:00
#
#         trip_duration   arrival_date_time
# 123   0 days 20:15:00 2019-03-02 19:15:00
# 396   0 days 06:25:00 2019-03-01 19:15:00
# 486   0 days 06:20:00 2019-03-01 15:15:00
# 510   0 days 05:25:00 2019-03-01 12:25:00
# 597   1 days 05:35:00 2019-03-07 15:15:00
# ...               ...                 ...
# 10353 0 days 21:00:00 2019-03-07 16:50:00
# 10364 0 days 04:40:00 2019-03-01 14:25:00
# 10383 0 days 22:05:00 2019-03-02 05:05:00
# 10439 0 days 14:20:00 2019-03-02 09:00:00
# 10511 1 days 02:40:00 2019-03-02 09:25:00
#
# [96 rows x 15 columns]

# %%
# Check for outliers
fig1 = px.histogram(df[(np.abs(stats.zscore(df["Price"])) < 3)], x="Price", histnorm='probability density',marginal="box")
#fig.update_layout(autosize=False,width=800,height=500,)
fig1.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="de0babe6-8c3c-42cc-91c6-7404809d58d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de0babe6-8c3c-42cc-91c6-7404809d58d4")) {                    Plotly.newPlot(                        "de0babe6-8c3c-42cc-91c6-7404809d58d4",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":"Price=%{x}<br>probability density=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[3897,7662,13882,6218,13302,3873,11087,22270,11087,8625,8907,4174,4667,9663,4804,14011,5830,10262,13381,12898,19495,6955,3943,4823,7757,13292,8238,7682,4668,3687,3687,13227,4423,10919,12373,5894,4649,6245,19225,14924,9646,8714,12373,3383,13062,3527,3943,4667,6117,11150,7202,12121,4377,3943,4483,14231,17345,7414,8073,12395,8366,5117,12524,7191,3687,5894,5403,3625,10861,6297,5678,9134,10791,12819,6893,7240,3898,4049,10262,3332,10844,7229,13941,5894,10197,13712,5636,13014,7064,10703,9646,17057,13817,13748,4880,3540,3257,6478,8040,14300,14781,14939,10262,6528,6121,13029,11421,7574,11596,15129,13555,5780,9397,17024,5281,10348,12677,15147,4668,15554,3971,3100,9663,3540,10676,13044,14388,3943,3597,5932,10262,6216,4804,14067,15129,13376,10441,4030,17024,13017,6686,5636,6442,9486,10844,15318,5117,6147,7005,3873,9270,3898,14781,8586,10697,14300,8855,10844,17024,9314,4777,7662,6442,5264,12898,6092,3311,6540,3419,5177,8246,14676,13587,9663,13044,5073,9345,9663,14277,10262,5678,13727,9663,3858,4812,5775,10539,4804,3383,8738,7165,6412,8016,11087,3543,12471,10262,4441,12537,10091,6961,5013,6934,10877,7229,7048,4878,10844,15129,3943,5583,9646,7677,6842,4995,9555,4077,7229,12192,5911,8372,4995,14323,13014,13591,18799,3943,1965,4995,14641,4460,10191,13843,6349,4409,17024,13727,8855,12524,13555,10844,13587,3543,4842,3943,10577,6979,11982,5264,8001,10651,10844,6601,6587,3173,5228,5769,14714,13014,3359,6722,4462,6171,12303,7695,5684,8366,19630,13502,14781,6513,9929,18275,4487,2754,2575,8224,8991,5000,8529,14042,4030,10844,4804,7308,4823,10262,12898,12778,14871,8708,10844,4129,4804,7229,7832,3859,9001,4878,2754,4668,5216,10368,8146,12242,9134,10939,11753,4174,10844,14714,9899,14871,7295,13465,3543,7198,10262,4148,8016,10262,3841,11507,14781,16079,12898,15353,7303,6197,8996,6528,4239,4148,3971,5192,9483,18804,5201,16079,7229,6795,10953,15965,9968,4804,16079,11507,11542,7229,4544,6496,4804,13439,6540,4591,4437,6151,7754,10262,8016,4781,4668,14594,14231,8425,9646,7295,5162,6860,6216,5192,4823,3919,2754,9315,11667,6224,13349,11087,15603,15129,4823,8452,12524,3384,10262,1965,4804,16079,13292,6751,8669,14871,12898,3919,3597,10741,11432,11087,13292,7631,13381,13731,11911,4591,14848,8266,12392,13044,12898,12242,3943,11105,14388,13014,15411,16289,6442,10844,5678,6906,3543,14714,11793,14323,3971,8452,5403,13727,12639,5198,4878,12373,8552,6741,6481,7354,5228,10844,6347,5013,9663,4823,13381,3543,9663,7064,10262,13013,15339,4937,6818,10441,5177,3858,6534,6795,9736,7229,4957,7648,3873,14388,5618,7408,13774,4668,13082,8669,6316,12583,7923,7378,4878,10844,7229,6297,8529,13727,6643,10197,4911,6482,3717,3597,10846,14069,5177,14641,6442,5704,9663,14714,5406,8610,14237,4823,2227,12373,8372,17024,3100,14053,3540,9345,10368,5755,7832,14388,8839,22096,3687,9627,13542,4423,8899,5583,6752,3543,7832,10991,12898,12898,3398,5201,13873,7384,10262,10031,12384,7757,17261,7298,7229,4174,5699,4880,15284,13759,16092,4392,10262,3841,5048,11096,5073,19828,3739,10598,7229,8610,6216,6961,10703,14151,8586,4488,7408,5443,10539,7723,15411,7229,4804,4050,14151,4957,7591,11134,6600,4966,15481,5515,14714,4959,7229,6094,4409,9794,5678,6442,4878,12446,16704,9134,8586,7229,6144,69 ...

# %% [markdown]
# #### Departure Date:

# %%
# 2nd Feature: `Date_of_Journey` unique values
sorted(df["Date_of_Journey"].unique())
# Out:
# ['01/03/2019',
#  '03/03/2019',
#  '06/03/2019',
#  '09/03/2019',
#  '1/03/2019',
#  '1/04/2019',
#  '1/05/2019',
#  '1/06/2019',
#  '12/03/2019',
#  '12/04/2019',
#  '12/05/2019',
#  '12/06/2019',
#  '15/03/2019',
#  '15/04/2019',
#  '15/05/2019',
#  '15/06/2019',
#  '18/03/2019',
#  '18/04/2019',
#  '18/05/2019',
#  '18/06/2019',
#  '21/03/2019',
#  '21/04/2019',
#  '21/05/2019',
#  '21/06/2019',
#  '24/03/2019',
#  '24/04/2019',
#  '24/05/2019',
#  '24/06/2019',
#  '27/03/2019',
#  '27/04/2019',
#  '27/05/2019',
#  '27/06/2019',
#  '3/03/2019',
#  '3/04/2019',
#  '3/05/2019',
#  '3/06/2019',
#  '6/03/2019',
#  '6/04/2019',
#  '6/05/2019',
#  '6/06/2019',
#  '9/03/2019',
#  '9/04/2019',
#  '9/05/2019',
#  '9/06/2019']

# %%
# `Date_of_Journey` value counts
df["Date_of_Journey"].value_counts()
# Out:
# 6/06/2019     489
# 18/05/2019    485
# 9/06/2019     482
# 12/06/2019    481
# 21/05/2019    481
# 9/05/2019     465
# 21/03/2019    411
# 15/05/2019    400
# 27/05/2019    368
# 27/06/2019    337
# 24/06/2019    328
# 1/06/2019     328
# 3/06/2019     325
# 15/06/2019    312
# 24/03/2019    312
# 6/03/2019     300
# 27/03/2019    290
# 24/05/2019    285
# 6/05/2019     279
# 1/05/2019     274
# 12/05/2019    257
# 1/04/2019     254
# 3/03/2019     216
# 9/03/2019     198
# 15/03/2019    162
# 18/03/2019    156
# 01/03/2019    148
# 12/03/2019    137
# 9/04/2019     125
# 3/04/2019     110
# 21/06/2019    109
# 18/06/2019    105
# 09/03/2019    100
# 6/04/2019     100
# 06/03/2019     94
# 27/04/2019     94
# 24/04/2019     92
# 3/05/2019      90
# 03/03/2019     90
# 15/04/2019     89
# 21/04/2019     82
# 18/04/2019     67
# 12/04/2019     63
# 1/03/2019      47
# Name: Date_of_Journey, dtype: int64

# %%
# Converting from Object to Datetime format
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'], format="%d/%m/%Y")

# %% [markdown]
# #### Departure Time:

# %%
# 6th Feature: `Dep_Time` unique values
df["Dep_Time"].unique()
# Out:
# array(['22:20', '05:50', '09:25', '18:05', '16:50', '09:00', '18:55',
#        '08:00', '08:55', '11:25', '09:45', '20:20', '11:40', '21:10',
#        '17:15', '16:40', '08:45', '14:00', '20:15', '16:00', '14:10',
#        '22:00', '04:00', '21:25', '21:50', '07:00', '07:05', '09:50',
#        '14:35', '10:35', '15:05', '14:15', '06:45', '20:55', '11:10',
#        '05:45', '19:00', '23:05', '11:00', '09:35', '21:15', '23:55',
#        '19:45', '08:50', '15:40', '06:05', '15:00', '13:55', '05:55',
#        '13:20', '05:05', '06:25', '17:30', '08:20', '19:55', '06:30',
#        '14:05', '02:00', '09:40', '08:25', '20:25', '13:15', '02:15',
#        '16:55', '20:45', '05:15', '19:50', '20:00', '06:10', '19:30',
#        '04:45', '12:55', '18:15', '17:20', '15:25', '23:00', '12:00',
#        '14:45', '11:50', '11:30', '14:40', '19:10', '06:00', '23:30',
#        '07:35', '13:05', '12:30', '15:10', '12:50', '18:25', '16:30',
#        '00:40', '06:50', '13:00', '19:15', '01:30', '17:00', '10:00',
#        '19:35', '15:30', '12:10', '16:10', '20:35', '22:25', '21:05',
#        '05:35', '05:10', '06:40', '15:15', '00:30', '08:30', '07:10',
#        '05:30', '14:25', '05:25', '10:20', '17:45', '13:10', '22:10',
#        '04:55', '17:50', '21:20', '06:20', '15:55', '20:30', '17:25',
#        '09:30', '07:30', '02:35', '10:55', '17:10', '09:10', '18:45',
#        '15:20', '22:50', '14:55', '14:20', '13:25', '22:15', '11:05',
#        '16:15', '20:10', '06:55', '19:05', '07:55', '07:45', '10:10',
#        '08:15', '11:35', '21:00', '17:55', '16:45', '18:20', '03:50',
#        '08:35', '19:20', '20:05', '17:40', '04:40', '17:35', '09:55',
#        '05:00', '18:00', '02:55', '20:40', '22:55', '22:40', '21:30',
#        '08:10', '17:05', '07:25', '15:45', '09:15', '15:50', '11:45',
#        '22:05', '18:35', '00:25', '19:40', '20:50', '22:45', '10:30',
#        '23:25', '11:55', '10:45', '11:15', '12:20', '14:30', '07:15',
#        '01:35', '18:40', '09:20', '21:55', '13:50', '01:40', '00:20',
#        '04:15', '13:45', '18:30', '06:15', '02:05', '12:15', '13:30',
#        '06:35', '10:05', '08:40', '03:05', '21:35', '16:35', '02:30',
#        '16:25', '05:40', '15:35', '13:40', '07:20', '04:50', '12:45',
#        '10:25', '12:05', '11:20', '21:40', '03:00'], dtype=object)

# %%
# `Dep_Time` value counts
df["Dep_Time"].value_counts()
# Out:
# 18:55    233
# 17:00    227
# 07:05    202
# 07:10    201
# 10:00    193
#         ...
# 22:25      1
# 16:25      1
# 21:35      1
# 04:15      1
# 03:00      1
# Name: Dep_Time, Length: 222, dtype: int64

# %%
# Converting from object to time format
df['Dep_Time'] = pd.to_datetime(df['Dep_Time'], format='%H:%M').dt.time#.dt.strftime('%H:%M')

# %%
# creating new column combining between Date_of_journey and Dep_time
df['dep_date_time'] = pd.to_datetime(df['Date_of_Journey'].astype(str) + ' ' + df['Dep_Time'].astype(str))

# %% [markdown]
# #### Flight Duration:

# %%
# 8th Feature: `Duration` unique values
df["Duration"].unique()
# Out:
# array(['2h 50m', '7h 25m', '19h', '5h 25m', '4h 45m', '2h 25m', '15h 30m',
#        '21h 5m', '25h 30m', '7h 50m', '13h 15m', '2h 35m', '2h 15m',
#        '12h 10m', '26h 35m', '4h 30m', '22h 35m', '23h', '20h 35m',
#        '5h 10m', '15h 20m', '2h 55m', '13h 20m', '15h 10m', '5h 45m',
#        '5h 55m', '13h 25m', '22h', '5h 30m', '10h 25m', '5h 15m',
#        '2h 30m', '6h 15m', '11h 55m', '11h 5m', '8h 30m', '22h 5m',
#        '2h 45m', '12h', '16h 5m', '19h 55m', '3h 15m', '25h 20m', '3h',
#        '16h 15m', '15h 5m', '6h 30m', '25h 5m', '12h 25m', '27h 20m',
#        '10h 15m', '10h 30m', '1h 30m', '1h 25m', '26h 30m', '7h 20m',
#        '13h 30m', '5h', '19h 5m', '14h 50m', '2h 40m', '22h 10m',
#        '9h 35m', '10h', '21h 20m', '18h 45m', '12h 20m', '18h', '9h 15m',
#        '17h 30m', '16h 35m', '12h 15m', '7h 30m', '24h', '8h 55m',
#        '7h 10m', '14h 30m', '30h 20m', '15h', '12h 45m', '10h 10m',
#        '15h 25m', '14h 5m', '20h 15m', '23h 10m', '18h 10m', '16h',
#        '2h 20m', '8h', '16h 55m', '3h 10m', '14h', '23h 50m', '21h 40m',
#        '21h 15m', '10h 50m', '8h 15m', '8h 35m', '11h 50m', '27h 35m',
#        '8h 25m', '20h 55m', '4h 50m', '8h 10m', '24h 25m', '23h 35m',
#        '25h 45m', '26h 10m', '28h 50m', '25h 15m', '9h 20m', '9h 10m',
#        '3h 5m', '11h 30m', '9h 30m', '17h 35m', '5h 5m', '25h 50m', '20h',
#        '13h', '18h 25m', '24h 10m', '4h 55m', '25h 35m', '6h 20m',
#        '18h 40m', '19h 25m', '29h 20m', '9h 5m', '10h 45m', '11h 40m',
#        '22h 55m', '37h 25m', '25h 40m', '13h 55m', '8h 40m', '23h 30m',
#        '12h 35m', '24h 15m', '1h 20m', '11h', '11h 15m', '14h 35m',
#        '12h 55m', '9h', '7h 40m', '11h 45m', '24h 55m', '17h 5m',
#        '29h 55m', '22h 15m', '14h 40m', '7h 15m', '20h 10m', '20h 45m',
#        '27h', '24h 30m', '20h 25m', '5h 35m', '14h 45m', '5h 40m',
#        '4h 5m', '15h 55m', '7h 45m', '28h 20m', '4h 20m', '3h 40m',
#        '8h 50m', '23h 45m', '24h 45m', '21h 35m', '8h 5m', '6h 25m',
#        '15h 50m', '24h 50m', '26h', '23h 5m', '7h 55m', '26h 20m',
#        '23h 15m', '5h 20m', '4h', '9h 45m', '8h 20m', '17h 25m', '7h 5m',
#        '34h 5m', '6h 5m', '5h 50m', '7h', '4h 25m', '13h 45m', '19h 15m',
#        '22h 30m', '16h 25m', '13h 50m', '27h 5m', '28h 10m', '4h 40m',
#        '15h 40m', '4h 35m', '18h 30m', '38h 15m', '6h 35m', '12h 30m',
#        '11h 20m', '7h 35m', '29h 35m', '26h 55m', '23h 40m', '12h 50m',
#        '9h 50m', '21h 55m', '10h 55m', '21h 10m', '20h 40m', '30h',
#        '13h 10m', '8h 45m', '6h 10m', '17h 45m', '21h 45m', '3h 55m',
#        '17h 20m', '30h 30m', '21h 25m', '12h 40m', '24h 35m', '19h 10m',
#        '22h 40m', '14h 55m', '21h', '6h 45m', '28h 40m', '9h 40m',
#        '16h 40m', '16h 20m', '16h 45m', '1h 15m', '6h 55m', '11h 25m',
#        '14h 20m', '12h 5m', '24h 5m', '28h 15m', '17h 50m', '20h 20m',
#        '28h 5m', '10h 20m', '14h 15m', '35h 35m', '26h 40m', '28h',
#        '14h 25m', '13h 5m', '37h 20m', '36h 10m', '25h 55m', '35h 5m',
#        '19h 45m', '27h 55m', '47h', '10h 35m', '1h 35m', '16h 10m',
#        '38h 20m', '6h', '16h 50m', '14h 10m', '23h 20m', '17h 40m',
#        '11h 35m', '18h 20m', '6h 40m', '30h 55m', '24h 40m', '29h 50m',
#        '28h 25m', '17h 15m', '22h 45m', '25h 25m', '21h 50m', '33h 15m',
#        '30h 15m', '3h 35m', '27h 40m', '18h 50m', '27h 45m', '15h 15m',
#        '10h 40m', '26h 15m', '36h 25m', '26h 50m', '15h 45m', '19h 40m',
#        '22h 25m', '19h 35m', '25h', '26h 45m', '4h 15m', '25h 10m',
#        '18h 15m', '6h 50m', '23h 55m', '17h 55m', '23h 25m', '17h 10m',
#        '24h 20m', '28h 30m', '27h 10m', '19h 20m', '15h 35m', '9h 25m',
#        '21h 30m', '34h 25m', '18h 35m', '29h 40m', '26h 5m', '29h 5m',
#        '27h 25m', '16h 30m', '11h 10m', '28h 55m', '29h 10m', '34h',
#        '30h 40m', '30h 45m', '32h 55m', '10h 5m', '32h 5m', '31h 40m',
#        '19h 50m', '33h 45m', '30h 10m', '13h 40m', '19h 30m', '31h 30m',
#        '34h 30m', '27h 50m', '38h 35m', '42h 5m', '4h 10m', '39h 5m',
#        '3h 50m', '5m', '32h 30m', '31h 55m', '33h 20m', '18h 55m',
#        '9h 55m', '26h 25m', '41h 20m', '20h 5m', '31h 50m', '42h 45m',
#        '3h 25m', '37h 10m', '32h 20m', '20h 50m', '40h 20m', '13h 35m',
#        '47h 40m'], dtype=object)

# %%
# `Duration` value counts
df["Duration"].value_counts()
# Out:
# 2h 50m     544
# 1h 30m     386
# 2h 45m     335
# 2h 55m     332
# 2h 35m     329
#           ...
# 33h 45m      1
# 30h 10m      1
# 31h 30m      1
# 42h 5m       1
# 47h 40m      1
# Name: Duration, Length: 362, dtype: int64

# %%
# Viewing anomally
df[df["Duration"]=="5m"]
# Out:
#         Airline Date_of_Journey  Source Destination                  Route  \
# 6474  Air India      2019-03-06  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD
#
#       Dep_Time Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 6474  16:50:00        16:55       5m     2 stops         No info  17327
#
#       routes_count       dep_date_time
# 6474             2 2019-03-06 16:50:00

# %% [markdown]
# Before dropping this anomally I have checked replacing the anomaly values `Duration`, `Arrival_Time`, `duration_hours` and `duration_minutes` with data similar fight information, but the result was creating a duplicated, therefore the best choice is to drop this anomally observation.

# %%
# Dropping anomally
df = df[df["Duration"] != "5m"]

# %%
# Create New flight duration feature
df['trip_duration'] = pd.to_timedelta(df['Duration'])  #/ pd.Timedelta(hours=1)

# %% [markdown]
# #### Arrival data & Time:

# %%
# 7th Feature: `Arrival_Time` unique values
df["Arrival_Time"].unique()
# Out:
# array(['01:10 22 Mar', '13:15', '04:25 10 Jun', ..., '06:50 10 Mar',
#        '00:05 19 Mar', '21:20 13 Mar'], dtype=object)

# %%
# `Arrival_Time` value counts
df["Arrival_Time"].value_counts()
# Out:
# 19:00           412
# 21:00           355
# 19:15           333
# 16:10           154
# 12:35           122
#                ...
# 00:50 02 Jun      1
# 00:25 02 Jun      1
# 08:55 13 Mar      1
# 11:05 19 May      1
# 21:20 13 Mar      1
# Name: Arrival_Time, Length: 1340, dtype: int64

# %% [markdown]
# * `Arrival_Time` contain alot of missing dates and conflect between deputure date, therefore it's better to create a new `arrival_date_time column`.

# %% [markdown]
# #### New Feature: Arrival date and time

# %%
# Creating a new Date and time feature for arrival date
df['arrival_date_time'] = df['dep_date_time'] + df['trip_duration']

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore       Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore       Delhi        BLR → NAG → DEL
#
#    Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0  22:20:00  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1  05:50:00         13:15   7h 25m     2 stops         No info   7662
# 2  09:25:00  04:25 10 Jun      19h     2 stops         No info  13882
# 3  18:05:00         23:30   5h 25m      1 stop         No info   6218
# 4  16:50:00         21:35   4h 45m      1 stop         No info  13302
#
#    routes_count       dep_date_time   trip_duration   arrival_date_time
# 0             0 2019-03-24 22:20:00 0 days 02:50:00 2019-03-25 01:10:00
# 1             2 2019-05-01 05:50:00 0 days 07:25:00 2019-05-01 13:15:00
# 2             2 2019-06-09 09:25:00 0 days 19:00:00 2019-06-10 04:25:00
# 3             1 2019-05-12 18:05:00 0 days 05:25:00 2019-05-12 23:30:00
# 4             1 2019-03-01 16:50:00 0 days 04:45:00 2019-03-01 21:35:00

# %%
# Reset the index of the dataframe
df = df.reset_index(drop=True)

# %% [markdown]
# #### Save dataframe to CSV

# %%
# Save the dataframe to a CSV file
df.to_csv('data_train_cleaned.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis - EDA

# %% [markdown]
# **Content:**
#
# 1. Univariate Analysis
# 2. Bivariate Analysis
# 3. Multivariate Analysis
# 4. Business Q & A.

# %%
# Download dataset from repo raw file link is a must to be able to load the file
#&> /dev/null
#!wget https://raw.githubusercontent.com/RamyGendy/Airline-Flight-Price-Prediction/main/data_train_cleaned.csv

# %%
# Loading our cleaned data as csv
df = pd.read_csv("data_train_cleaned.csv")

# %%
# Explore first 5 observations
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# Dataframe shape
df.shape
# Out:
# (10683, 11)

# %%
# Information Summery
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
# Statistical Description
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
# View dataframe columns
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# ### Univariate Analysis

# %%
base_color = sns.color_palette()[0]

ax1 = sns.countplot(data=df, y="Airline", color = base_color, order=df['Airline'].value_counts().index)
ax1.bar_label(ax1.containers[0]);

# %%
# Return the Series having unique values
x = df['Source'].unique()

# Return the Series having frequency count of each unique value
y = df['Source'].value_counts().sort_values()

plt.barh(x, y)

# Labeling the axes
plt.xlabel('count')
plt.ylabel('Source')
plt.xticks(rotation=90)
# Dsiplay the plot
plt.show();

# %%
base_color = sns.color_palette()[0]

ax2 = sns.countplot(data=df, y="Destination", color = base_color, order=df['Destination'].value_counts().index)
ax2.bar_label(ax2.containers[0]);

# %%
ax3 = sns.countplot(data=df, y="Total_Stops", color = base_color, order=df['Total_Stops'].value_counts().index)
ax3.bar_label(ax3.containers[0]);

# %%
ax4 = sns.countplot(data=df, y="Additional_Info", color = base_color, order=df['Additional_Info'].value_counts().index)
ax4.bar_label(ax4.containers[0]);

# %% [markdown]
# ### Bivariate Analysis

# %%
# 
sns.boxplot(x='Airline', y='Price', data=df.sort_values('Price', ascending=False));

# %%
# 
sns.boxplot(x='Source', y='Price', data=df.sort_values('Price', ascending=False));

# %%
#
sns.boxplot(x='Destination', y='Price', data=df.sort_values('Price', ascending=False));

# %%
# 
#plt.figure(figsize=(15,8))
sns.boxplot(x='Total_Stops', y='Price', data=df.sort_values('Price', ascending=False));

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# **Content:**
#
# 1. Feature Extraction
# 2. Feature Selection
# 3. Feature Transformation

# %% [markdown]
# Handling Categorical Data
#
# * Nominal data (data are not in any order): `OneHotEncoder`.
#
# * Ordinal data (data are in order): `LabelEncoder`.

# %%
'''
# Utilizing GPU Processors on Colab
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
'''
# Out:
# "\n# Utilizing GPU Processors on Colab\ndevice_name = tf.test.gpu_device_name()\nif device_name != '/device:GPU:0':\n  raise SystemError('GPU device not found')\nprint('Found GPU at: {}'.format(device_name))\n"
